# %% [markdown]
# <a href="https://colab.research.google.com/github/ruslanmv/Neural-Networks-from-Scratch/blob/master/4_Tunning_and_Training_model_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing library
# Neural Networks
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
import numpy as np
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import SGD

# %%
#Helper functions about mmorpg-ai project
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import io
from IPython.display import clear_output, Image, display
import PIL.Image
from matplotlib import pyplot as plt
import logging, sys
logging.disable(sys.maxsize)
import os

def df_to_numpy_image(df_image_clean,index):
    #select the row with index label 'index'
    image_clean=df_image_clean.loc[[index]].T.to_numpy()
    lists =image_clean.tolist()
    # Nested List Comprehension to flatten a given 2-D matrix
    # 2-D List
    matrix = lists
    flatten_matrix = [val.tolist() for sublist in matrix for val in sublist]
    # converting list to array
    arr = np.array(flatten_matrix)
    return arr
def df_to_numpy_input(df_input,index): 
    # flattening a 2d numpy array
    # into 1d array
    # and remove dtype at the end of numpy array
    lista=df_input.loc[[index]].values.tolist()
    arr=np.array(lista).ravel()
    return arr
#round a float up to next even number
import math
def roundeven(f):
    return math.ceil(f / 2.) * 2

# %%
#We define the parameters
width= 480
height= 270
ncolors=3
#Normalization Parameter
Norma        = 29/1000
#Paramters                          Operation 
filters1     =  roundeven(96*Norma)   #1
kernel1      =  11       
stride1      =  4
kernel2      =  3                     #2
stride2      =  2
filters3     =  roundeven(256*Norma)  #3
kernel3      =  5
kernel4      =  3                     #4
stride4      =  2
filters5     =  roundeven(384*Norma)  #5
kernel5      =  3
filters6     =  roundeven(384*Norma)  #6
kernel6      =  3
filters7     =  roundeven(256*Norma)  #7
kernel7      =  3
kernel8      =  3                      #8
stride8      =  2 
activation9  =  roundeven(4096*Norma)  #9
activation10 =  roundeven(4096*Norma)  #10
outputs11    =  int(1000*Norma)   #11
dropout13=0.5
dropout15=0.5
learning_rate17=0.001

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# %%
#We load the datasets to work
import os
user = "ruslanmv"
repo = "Neural-Networks-from-Scratch"
# remove local directory if it already exists
if os.path.isdir(repo):
    # !rm -rf {repo}
# !git clone https://github.com/{user}/{repo}.git
# Out:
# Cloning into 'Neural-Networks-from-Scratch'...
# remote: Enumerating objects: 190, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 190 (delta 67), reused 36 (delta 16), pack-reused 84
# Receiving objects: 100% (190/190), 318.15 MiB | 33.17 MiB/s, done.
# Resolving deltas: 100% (92/92), done.
# Checking out files: 100% (54/54), done.

# %%
import os
os.chdir('Neural-Networks-from-Scratch')

# %%
# !ls /content/Neural-Networks-from-Scratch/data
# Out:
# dfx-0.pkl  dfx-1.pkl  dfx-2.pkl  dfy-0.pkl  dfy-1.pkl  dfy-2.pkl

# %%
# Function to create model MmoNet
def create_model(optimizer='adam',learn_rate=0.1, momentum=0):
    # create model
    MmoNet = Sequential()
    MmoNet.add(Conv2D(filters=filters1, input_shape=(height, width, ncolors), kernel_size=(11,11), strides=(stride1,stride1), padding='same'))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('relu'))
    MmoNet.add(MaxPooling2D(pool_size=(kernel2,kernel2), strides=(stride2,stride2), padding='same'))
    MmoNet.add(Conv2D(filters=filters3, kernel_size=(kernel3, kernel3), padding='same'))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('relu'))
    MmoNet.add(MaxPooling2D(pool_size=(kernel4,kernel4), strides=(stride4,stride4), padding='same'))
    #3rd Convolutional Layer
    MmoNet.add(Conv2D(filters=filters5, kernel_size=(kernel5,kernel5), padding='same'))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('relu'))
    #4th Convolutional Layer
    MmoNet.add(Conv2D(filters=filters6, kernel_size=( kernel6, kernel6), padding='same'))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('relu'))
    #5th Convolutional Layer
    MmoNet.add(Conv2D(filters=filters7, kernel_size=(kernel7,kernel7),  padding='same'))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('relu'))
    MmoNet.add(MaxPooling2D(pool_size=(kernel8,kernel8), strides=(stride8,stride8), padding='same'))
    #Passing it to a Fully Connected layer
    MmoNet.add(Flatten())
    # 1st Fully Connected Layer
    MmoNet.add(Dense(activation9, input_shape=(270, 480, 3,)))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('relu'))
    # Add Dropout to prevent overfitting
    MmoNet.add(Dropout(dropout13))
    #2nd Fully Connected Layer
    MmoNet.add(Dense(activation10))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('relu'))
    #Add Dropout
    MmoNet.add(Dropout(dropout15))
    #3rd Fully Connected Layer
    MmoNet.add(Dense(1000))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('relu'))
    #Add Dropout
    MmoNet.add(Dropout(dropout15))
    #Output Layer
    MmoNet.add(Dense(outputs11))
    MmoNet.add(BatchNormalization())
    MmoNet.add(Activation('softmax'))

    # Compile model
    optimizer = SGD(learning_rate=learn_rate, momentum=momentum)
    

    MmoNet.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return MmoNet

# %%
model = create_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 68, 120, 4)        1456
#
#  batch_normalization (BatchN  (None, 68, 120, 4)       16
#  ormalization)
#
#  activation (Activation)     (None, 68, 120, 4)        0
#
#  max_pooling2d (MaxPooling2D  (None, 34, 60, 4)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 34, 60, 8)         808
#
#  batch_normalization_1 (Batc  (None, 34, 60, 8)        32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 34, 60, 8)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 17, 30, 8)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 17, 30, 12)        876
#
#  batch_normalization_2 (Batc  (None, 17, 30, 12)       48
#  hNormalization)
#
#  activation_2 (Activation)   (None, 17, 30, 12)        0
#
#  conv2d_3 (Conv2D)           (None, 17, 30, 12)        1308
#
#  batch_normalization_3 (Batc  (None, 17, 30, 12)       48
#  hNormalization)
#
#  activation_3 (Activation)   (None, 17, 30, 12)        0
#
#  conv2d_4 (Conv2D)           (None, 17, 30, 8)         872
#
#  batch_normalization_4 (Batc  (None, 17, 30, 8)        32
#  hNormalization)
#
#  activation_4 (Activation)   (None, 17, 30, 8)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 15, 8)         0
#  2D)
#
#  flatten (Flatten)           (None, 1080)              0
#
#  dense (Dense)               (None, 120)               129720
#
#  batch_normalization_5 (Batc  (None, 120)              480
#  hNormalization)
#
#  activation_5 (Activation)   (None, 120)               0
#
#  dropout (Dropout)           (None, 120)               0
#
#  dense_1 (Dense)             (None, 120)               14520
#
#  batch_normalization_6 (Batc  (None, 120)              480
#  hNormalization)
#
#  activation_6 (Activation)   (None, 120)               0
#
#  dropout_1 (Dropout)         (None, 120)               0
#
#  dense_2 (Dense)             (None, 1000)              121000
#
#  batch_normalization_7 (Batc  (None, 1000)             4000
#  hNormalization)
#
#  activation_7 (Activation)   (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 29)                29029
#
#  batch_normalization_8 (Batc  (None, 29)               116
#  hNormalization)
#
#  activation_8 (Activation)   (None, 29)                0
#
# =================================================================
# Total params: 304,841
# Trainable params: 302,215
# Non-trainable params: 2,626
# _________________________________________________________________

# %%
# load dataset
#We load the images of the gameplay
x_training_data=pd.read_pickle('data/dfx-0.pkl')  
#We load the inputs of the of the gameplay
y_training_data=pd.read_pickle('data/dfy-0.pkl')  
X_train, X_valid, y_train, y_valid = train_test_split(x_training_data, y_training_data, test_size=0.2, random_state=6)
# Train Image part ( 4 Dimensional)
X_image = np.array([df_to_numpy_image(X_train,i) for i in X_train.index])
X=X_image.reshape(-1,width,height,3)
#Train Input part ( 1 Dimensional )
Y = [df_to_numpy_input(y_train,i) for i in y_train.index]
# Test Image part ( 4 Dimensional)
test_image = np.array([df_to_numpy_image(X_valid,i) for i in X_valid.index])
test_x=test_image.reshape(-1,width,height,3)
## Test Input part( 1 Dimensional )
test_y = [df_to_numpy_input(y_valid,i) for i in y_valid.index]

# %%
X_image.shape
# Out:
# (200, 270, 480, 3)

# %%
type(X_image)
# Out:
# numpy.ndarray

# %%
Y_input=np.array(Y)

# %%
Y_input.shape
# Out:
# (200, 29)

# %%
test_image.shape
# Out:
# (50, 270, 480, 3)

# %%
test_input=np.array(test_y)

# %%
test_input.shape
# Out:
# (50, 29)

# %%
X_train = X_image
y_train = Y_input
X_test=  test_image
y_test = test_input

# %%
hist = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=80)
#hist = model.fit(X_image, Y_input, validation_data=(test_image, test_input), epochs=100, batch_size=80)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 14s 501ms/step - loss: 0.8039 - accuracy: 0.0350 - val_loss: 0.7208 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 3/3 [==============================] - 0s 178ms/step - loss: 0.8010 - accuracy: 0.0150 - val_loss: 0.7073 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 3/3 [==============================] - 0s 157ms/step - loss: 0.7989 - accuracy: 0.0200 - val_loss: 0.6982 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.7948 - accuracy: 0.0550 - val_loss: 0.6920 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.7920 - accuracy: 0.0400 - val_loss: 0.6847 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.7894 - accuracy: 0.0350 - val_loss: 0.6812 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.7864 - accuracy: 0.0300 - val_loss: 0.6763 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7829 - accuracy: 0.0350 - val_loss: 0.6716 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 3/3 [==============================] - 1s 164ms/step - loss: 0.7803 - accuracy: 0.0350 - val_loss: 0.6674 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 3/3 [==============================] - 1s 210ms/step - loss: 0.7771 - accuracy: 0.0150 - val_loss: 0.6636 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 3/3 [==============================] - 1s 196ms/step - loss: 0.7751 - accuracy: 0.0400 - val_loss: 0.6601 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 3/3 [==============================] - 1s 171ms/step - loss: 0.7714 - accuracy: 0.0500 - val_loss: 0.6563 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 3/3 [==============================] - 0s 170ms/step - loss: 0.7687 - accuracy: 0.0450 - val_loss: 0.6528 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7661 - accuracy: 0.0450 - val_loss: 0.6500 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.7630 - accuracy: 0.0400 - val_loss: 0.6470 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 3/3 [==============================] - 0s 190ms/step - loss: 0.7600 - accuracy: 0.0300 - val_loss: 0.6439 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 3/3 [==============================] - 0s 168ms/step - loss: 0.7572 - accuracy: 0.0400 - val_loss: 0.6410 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7548 - accuracy: 0.0600 - val_loss: 0.6386 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 3/3 [==============================] - 0s 169ms/step - loss: 0.7517 - accuracy: 0.0450 - val_loss: 0.6362 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.7491 - accuracy: 0.0350 - val_loss: 0.6321 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.7455 - accuracy: 0.0550 - val_loss: 0.6309 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7434 - accuracy: 0.0400 - val_loss: 0.6283 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.7408 - accuracy: 0.0400 - val_loss: 0.6263 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 3/3 [==============================] - 0s 186ms/step - loss: 0.7385 - accuracy: 0.0450 - val_loss: 0.6223 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 3/3 [==============================] - 1s 194ms/step - loss: 0.7349 - accuracy: 0.0450 - val_loss: 0.6201 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 3/3 [==============================] - 0s 180ms/step - loss: 0.7323 - accuracy: 0.0600 - val_loss: 0.6184 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 3/3 [==============================] - 0s 171ms/step - loss: 0.7294 - accuracy: 0.0450 - val_loss: 0.6160 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7269 - accuracy: 0.0700 - val_loss: 0.6165 - val_accuracy: 0.0200
# Epoch 29/100
# 3/3 [==============================] - 0s 171ms/step - loss: 0.7238 - accuracy: 0.0550 - val_loss: 0.6128 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7210 - accuracy: 0.0450 - val_loss: 0.6119 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7193 - accuracy: 0.0700 - val_loss: 0.6093 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7161 - accuracy: 0.0600 - val_loss: 0.6077 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 3/3 [==============================] - 0s 175ms/step - loss: 0.7125 - accuracy: 0.0700 - val_loss: 0.6043 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.7102 - accuracy: 0.0450 - val_loss: 0.6017 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.7080 - accuracy: 0.0700 - val_loss: 0.5990 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 3/3 [==============================] - 0s 167ms/step - loss: 0.7054 - accuracy: 0.0750 - val_loss: 0.5976 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.7028 - accuracy: 0.0750 - val_loss: 0.5961 - val_accuracy: 0.0400
# Epoch 38/100
# 3/3 [==============================] - 0s 172ms/step - loss: 0.7002 - accuracy: 0.0900 - val_loss: 0.5925 - val_accuracy: 0.0400
# Epoch 39/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.6974 - accuracy: 0.0550 - val_loss: 0.5920 - val_accuracy: 0.0400
# Epoch 40/100
# 3/3 [==============================] - 0s 158ms/step - loss: 0.6949 - accuracy: 0.0800 - val_loss: 0.5923 - val_accuracy: 0.0200
# Epoch 41/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.6919 - accuracy: 0.0550 - val_loss: 0.5913 - val_accuracy: 0.0600
# Epoch 42/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.6904 - accuracy: 0.0600 - val_loss: 0.5885 - val_accuracy: 0.0800
# Epoch 43/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.6875 - accuracy: 0.0900 - val_loss: 0.5869 - val_accuracy: 0.0800
# Epoch 44/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.6847 - accuracy: 0.0800 - val_loss: 0.5828 - val_accuracy: 0.0800
# Epoch 45/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.6821 - accuracy: 0.0700 - val_loss: 0.5788 - val_accuracy: 0.0800
# Epoch 46/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.6802 - accuracy: 0.0700 - val_loss: 0.5720 - val_accuracy: 0.1400
# Epoch 47/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.6772 - accuracy: 0.0700 - val_loss: 0.5696 - val_accuracy: 0.1600
# Epoch 48/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.6747 - accuracy: 0.1050 - val_loss: 0.5707 - val_accuracy: 0.1000
# Epoch 49/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.6720 - accuracy: 0.0600 - val_loss: 0.5714 - val_accuracy: 0.1800
# Epoch 50/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.6695 - accuracy: 0.0650 - val_loss: 0.5705 - val_accuracy: 0.2800
# Epoch 51/100
# 3/3 [==============================] - 0s 168ms/step - loss: 0.6669 - accuracy: 0.0750 - val_loss: 0.5684 - val_accuracy: 0.2800
# Epoch 52/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.6653 - accuracy: 0.0500 - val_loss: 0.5641 - val_accuracy: 0.2000
# Epoch 53/100
# 3/3 [==============================] - 0s 168ms/step - loss: 0.6620 - accuracy: 0.1000 - val_loss: 0.5625 - val_accuracy: 0.2800
# Epoch 54/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.6599 - accuracy: 0.1000 - val_loss: 0.5608 - val_accuracy: 0.2400
# Epoch 55/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.6579 - accuracy: 0.0900 - val_loss: 0.5573 - val_accuracy: 0.2800
# Epoch 56/100
# 3/3 [==============================] - 0s 168ms/step - loss: 0.6547 - accuracy: 0.0850 - val_loss: 0.5559 - val_accuracy: 0.2800
# Epoch 57/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.6522 - accuracy: 0.0700 - val_loss: 0.5533 - val_accuracy: 0.3800
# Epoch 58/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.6510 - accuracy: 0.1050 - val_loss: 0.5482 - val_accuracy: 0.3800
# Epoch 59/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.6479 - accuracy: 0.0900 - val_loss: 0.5451 - val_accuracy: 0.3200
# Epoch 60/100
# 3/3 [==============================] - 0s 167ms/step - loss: 0.6461 - accuracy: 0.0950 - val_loss: 0.5473 - val_accuracy: 0.3000
# Epoch 61/100
# 3/3 [==============================] - 0s 168ms/step - loss: 0.6430 - accuracy: 0.1200 - val_loss: 0.5437 - val_accuracy: 0.3200
# Epoch 62/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.6400 - accuracy: 0.1450 - val_loss: 0.5438 - val_accuracy: 0.3200
# Epoch 63/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.6391 - accuracy: 0.0850 - val_loss: 0.5418 - val_accuracy: 0.3200
# Epoch 64/100
# 3/3 [==============================] - 0s 191ms/step - loss: 0.6363 - accuracy: 0.1050 - val_loss: 0.5376 - val_accuracy: 0.2800
# Epoch 65/100
# 3/3 [==============================] - 0s 168ms/step - loss: 0.6348 - accuracy: 0.1200 - val_loss: 0.5349 - val_accuracy: 0.3000
# Epoch 66/100
# 3/3 [==============================] - 0s 193ms/step - loss: 0.6320 - accuracy: 0.1050 - val_loss: 0.5357 - val_accuracy: 0.3600
# Epoch 67/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.6292 - accuracy: 0.1200 - val_loss: 0.5340 - val_accuracy: 0.4000
# Epoch 68/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.6270 - accuracy: 0.0950 - val_loss: 0.5303 - val_accuracy: 0.3000
# Epoch 69/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.6251 - accuracy: 0.1250 - val_loss: 0.5276 - val_accuracy: 0.3600
# Epoch 70/100
# 3/3 [==============================] - 0s 167ms/step - loss: 0.6225 - accuracy: 0.1350 - val_loss: 0.5247 - val_accuracy: 0.3800
# Epoch 71/100
# 3/3 [==============================] - 0s 168ms/step - loss: 0.6202 - accuracy: 0.1000 - val_loss: 0.5229 - val_accuracy: 0.3400
# Epoch 72/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.6173 - accuracy: 0.1150 - val_loss: 0.5203 - val_accuracy: 0.4000
# Epoch 73/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.6158 - accuracy: 0.1150 - val_loss: 0.5193 - val_accuracy: 0.3600
# Epoch 74/100
# 3/3 [==============================] - 0s 191ms/step - loss: 0.6139 - accuracy: 0.1100 - val_loss: 0.5174 - val_accuracy: 0.3600
# Epoch 75/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.6110 - accuracy: 0.1050 - val_loss: 0.5136 - val_accuracy: 0.4200
# Epoch 76/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.6092 - accuracy: 0.1050 - val_loss: 0.5126 - val_accuracy: 0.3600
# Epoch 77/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.6073 - accuracy: 0.1200 - val_loss: 0.5116 - val_accuracy: 0.3600
# Epoch 78/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.6049 - accuracy: 0.1250 - val_loss: 0.5079 - val_accuracy: 0.3200
# Epoch 79/100
# 3/3 [==============================] - 0s 167ms/step - loss: 0.6026 - accuracy: 0.1450 - val_loss: 0.5050 - val_accuracy: 0.3400
# Epoch 80/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.6003 - accuracy: 0.1050 - val_loss: 0.5012 - val_accuracy: 0.3200
# Epoch 81/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.5987 - accuracy: 0.1450 - val_loss: 0.5002 - val_accuracy: 0.3600
# Epoch 82/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.5972 - accuracy: 0.1500 - val_loss: 0.4991 - val_accuracy: 0.4000
# Epoch 83/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.5944 - accuracy: 0.1200 - val_loss: 0.4983 - val_accuracy: 0.3800
# Epoch 84/100
# 3/3 [==============================] - 0s 174ms/step - loss: 0.5917 - accuracy: 0.1400 - val_loss: 0.4978 - val_accuracy: 0.3600
# Epoch 85/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.5895 - accuracy: 0.1150 - val_loss: 0.4939 - val_accuracy: 0.3200
# Epoch 86/100
# 3/3 [==============================] - 0s 174ms/step - loss: 0.5875 - accuracy: 0.1550 - val_loss: 0.4919 - val_accuracy: 0.3200
# Epoch 87/100
# 3/3 [==============================] - 0s 171ms/step - loss: 0.5857 - accuracy: 0.1750 - val_loss: 0.4892 - val_accuracy: 0.3000
# Epoch 88/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.5841 - accuracy: 0.1900 - val_loss: 0.4920 - val_accuracy: 0.3600
# Epoch 89/100
# 3/3 [==============================] - 0s 169ms/step - loss: 0.5817 - accuracy: 0.1850 - val_loss: 0.4900 - val_accuracy: 0.3800
# Epoch 90/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.5795 - accuracy: 0.2000 - val_loss: 0.4898 - val_accuracy: 0.3600
# Epoch 91/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.5767 - accuracy: 0.1700 - val_loss: 0.4880 - val_accuracy: 0.3400
# Epoch 92/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.5755 - accuracy: 0.1650 - val_loss: 0.4881 - val_accuracy: 0.3800
# Epoch 93/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.5732 - accuracy: 0.1250 - val_loss: 0.4861 - val_accuracy: 0.3600
# Epoch 94/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.5715 - accuracy: 0.1950 - val_loss: 0.4837 - val_accuracy: 0.3600
# Epoch 95/100
# 3/3 [==============================] - 0s 169ms/step - loss: 0.5690 - accuracy: 0.1550 - val_loss: 0.4814 - val_accuracy: 0.3800
# Epoch 96/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.5675 - accuracy: 0.2500 - val_loss: 0.4779 - val_accuracy: 0.4000
# Epoch 97/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.5659 - accuracy: 0.1450 - val_loss: 0.4755 - val_accuracy: 0.3600
# Epoch 98/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.5637 - accuracy: 0.2050 - val_loss: 0.4761 - val_accuracy: 0.4200
# Epoch 99/100
# 3/3 [==============================] - 0s 167ms/step - loss: 0.5616 - accuracy: 0.1950 - val_loss: 0.4747 - val_accuracy: 0.4000
# Epoch 100/100
# 3/3 [==============================] - 0s 127ms/step - loss: 0.5583 - accuracy: 0.1850 - val_loss: 0.4729 - val_accuracy: 0.3200

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set()
acc = hist.history['accuracy']
val = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training accuracy')
plt.plot(epochs, val, ':', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import confusion_matrix
y_predicted = model.predict(X_test) > 0.5
#mat = confusion_matrix(y_test, y_predicted)
mat = confusion_matrix(np.asarray(y_test).argmax(axis=1), np.asarray(y_predicted).argmax(axis=1))
labels_input=list(y_training_data.columns)
labels = labels_input

# %%
ax= plt.subplot()
sns.heatmap(mat, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(labels); ax.yaxis.set_ticklabels(labels);

# %%
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# Text(89.18, 0.5, 'Actual label')

# %%
# !pip install keras-tuner -q
# Out:
#      |████████████████████████████████| 133 kB 8.6 MB/s

# %%
x_train = X_image
x_val=  test_image

# %%
#%matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.imshow(x_train[0], cmap='binary')
plt.xlabel(y_train[0])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
y_train = np.array(Y)
y_val = np.array(test_y)

# %%
import keras_tuner
import tensorflow as tf

# %%
class MyHyperModel(keras_tuner.HyperModel):
    def build(self, hp):
        """Builds a convolutional model."""
        # create model
        input_shape =(270, 480, 3)
        optimizer='Adam'
        learn_rate=0.1
        momentum=0

        # create model
        MmoNet = Sequential()
        MmoNet.add(Conv2D(filters=filters1, input_shape=(height, width, ncolors), kernel_size=(11,11), strides=(stride1,stride1), padding='same'))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('relu'))
        MmoNet.add(MaxPooling2D(pool_size=(kernel2,kernel2), strides=(stride2,stride2), padding='same'))
        MmoNet.add(Conv2D(filters=filters3, kernel_size=(kernel3, kernel3), padding='same'))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('relu'))
        MmoNet.add(MaxPooling2D(pool_size=(kernel4,kernel4), strides=(stride4,stride4), padding='same'))
        #3rd Convolutional Layer
        MmoNet.add(Conv2D(filters=filters5, kernel_size=(kernel5,kernel5), padding='same'))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('relu'))
        #4th Convolutional Layer
        MmoNet.add(Conv2D(filters=filters6, kernel_size=( kernel6, kernel6), padding='same'))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('relu'))
        #5th Convolutional Layer
        MmoNet.add(Conv2D(filters=filters7, kernel_size=(kernel7,kernel7),  padding='same'))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('relu'))
        MmoNet.add(MaxPooling2D(pool_size=(kernel8,kernel8), strides=(stride8,stride8), padding='same'))
        #Passing it to a Fully Connected layer
        MmoNet.add(Flatten())
        # 1st Fully Connected Layer
        MmoNet.add(Dense(hp.Choice('units1', [8, 16, 32,64,128,256,512,1024]), input_shape=(270, 480, 3,)))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('relu'))
        # Add Dropout to prevent overfitting
        MmoNet.add(Dropout(hp.Choice('Dropout1', [0.25,0.5,0.75])))
        #2nd Fully Connected Layer
        MmoNet.add(Dense(hp.Choice('units2', [8, 16, 32,64,128,256,512,1024])))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('relu'))
        #Add Dropout
        MmoNet.add(Dropout(hp.Choice('Dropout2', [0.25,0.5,0.75])))
        #3rd Fully Connected Layer
        MmoNet.add(Dense(hp.Choice('units3', [8, 16, 32,64,128,256,512,1024])))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('relu'))
        #Add Dropout
        MmoNet.add(Dropout(hp.Choice('Dropout3', [0.25,0.5,0.75])))
        #Output Layer
        MmoNet.add(Dense(outputs11))
        MmoNet.add(BatchNormalization())
        MmoNet.add(Activation('softmax'))

        # Compile model
        optimizer = SGD(learning_rate=learn_rate, momentum=momentum)
        MmoNet.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
        return MmoNet


    def fit(self, hp, model, x, y, validation_data, callbacks=None, **kwargs):
        # Convert the datasets to tf.data.Dataset.
        batch_size = hp.Int("batch_size", 32, 128, step=32, default=64)
        train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(
            batch_size
        )
        validation_data = tf.data.Dataset.from_tensor_slices(validation_data).batch(
            batch_size
        )

        # Define the optimizer.
        optimizer = tf.keras.optimizers.Adam(
            hp.Float("learning_rate", 1e-4, 1e-2, sampling="log", default=1e-3)
        )
        loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=True)

        # The metric to track validation loss.
        epoch_loss_metric = tf.keras.metrics.Mean()

        # Function to run the train step.
        @tf.function
        def run_train_step(images, labels):
            with tf.GradientTape() as tape:
                logits = model(images)
                loss = loss_fn(labels, logits)
                # Add any regularization losses.
                if model.losses:
                    loss += tf.math.add_n(model.losses)
            gradients = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, model.trainable_variables))

        # Function to run the validation step.
        @tf.function
        def run_val_step(images, labels):
            logits = model(images)
            loss = loss_fn(labels, logits)
            # Update the metric.
            epoch_loss_metric.update_state(loss)

        # Assign the model to the callbacks.
        for callback in callbacks:
            callback.model = model

        # Record the best validation loss value
        best_epoch_loss = float("inf")

        # The custom training loop.
        for epoch in range(2):
            print(f"Epoch: {epoch}")

            # Iterate the training data to run the training step.
            for images, labels in train_ds:
                run_train_step(images, labels)

            # Iterate the validation data to run the validation step.
            for images, labels in validation_data:
                run_val_step(images, labels)

            # Calling the callbacks after epoch.
            epoch_loss = float(epoch_loss_metric.result().numpy())
            for callback in callbacks:
                # The "my_metric" is the objective passed to the tuner.
                callback.on_epoch_end(epoch, logs={"my_metric": epoch_loss})
            epoch_loss_metric.reset_states()

            print(f"Epoch loss: {epoch_loss}")
            best_epoch_loss = min(best_epoch_loss, epoch_loss)

        # Return the evaluation metric value.
        return best_epoch_loss

# %%
tuner = keras_tuner.RandomSearch(
    objective=keras_tuner.Objective("my_metric", "min"),
    max_trials=10,
    hypermodel=MyHyperModel(),
    directory="results",
    project_name="custom_training",
    overwrite=True,
)

# %%
tuner.search(x=x_train, y=y_train, validation_data=(x_val, y_val))
# Out:
# Trial 2 Complete [00h 00m 03s]
# my_metric: 2.8676042556762695
#
# Best my_metric So Far: 1.9900518655776978
# Total elapsed time: 00h 00m 07s

# %%
best_hps = tuner.get_best_hyperparameters()[0]
print(best_hps.values)
# Out:
# {'units1': 512, 'Dropout1': 0.5, 'units2': 8, 'Dropout2': 0.5, 'units3': 64, 'Dropout3': 0.25, 'batch_size': 64, 'learning_rate': 0.001}

# %%
#tuner.search(x=x_train, y=y_train, epochs=5,validation_data=(x_val, y_val))
#tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val))
# Will stop training if the "val_loss" hasn't improved in 3 epochs.
tuner.search(x_train, y_train, epochs=30, callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=3)],validation_data=(x_val, y_val))
# Out:
# Trial 10 Complete [00h 00m 03s]
# my_metric: 17.2844295501709
#
# Best my_metric So Far: 2.0432987213134766
# Total elapsed time: 00h 00m 39s

# %%
best_hps = tuner.get_best_hyperparameters()[0]
print(best_hps.values)
# Out:
# {'units1': 32, 'Dropout1': 0.5, 'units2': 128, 'Dropout2': 0.25, 'units3': 64, 'Dropout3': 0.5, 'batch_size': 96, 'learning_rate': 0.0013182933088237972}

# %%
best_model = tuner.get_best_models()[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 68, 120, 4)        1456
#
#  batch_normalization (BatchN  (None, 68, 120, 4)       16
#  ormalization)
#
#  activation (Activation)     (None, 68, 120, 4)        0
#
#  max_pooling2d (MaxPooling2D  (None, 34, 60, 4)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 34, 60, 8)         808
#
#  batch_normalization_1 (Batc  (None, 34, 60, 8)        32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 34, 60, 8)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 17, 30, 8)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 17, 30, 12)        876
#
#  batch_normalization_2 (Batc  (None, 17, 30, 12)       48
#  hNormalization)
#
#  activation_2 (Activation)   (None, 17, 30, 12)        0
#
#  conv2d_3 (Conv2D)           (None, 17, 30, 12)        1308
#
#  batch_normalization_3 (Batc  (None, 17, 30, 12)       48
#  hNormalization)
#
#  activation_3 (Activation)   (None, 17, 30, 12)        0
#
#  conv2d_4 (Conv2D)           (None, 17, 30, 8)         872
#
#  batch_normalization_4 (Batc  (None, 17, 30, 8)        32
#  hNormalization)
#
#  activation_4 (Activation)   (None, 17, 30, 8)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 15, 8)         0
#  2D)
#
#  flatten (Flatten)           (None, 1080)              0
#
#  dense (Dense)               (None, 32)                34592
#
#  batch_normalization_5 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation_5 (Activation)   (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 128)               4224
#
#  batch_normalization_6 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_6 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_7 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 29)                1885
#
#  batch_normalization_8 (Batc  (None, 29)               116
#  hNormalization)
#
#  activation_8 (Activation)   (None, 29)                0
#
# =================================================================
# Total params: 55,465
# Trainable params: 54,871
# Non-trainable params: 594
# _________________________________________________________________

# %%
best_hist = best_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=300, batch_size=96)
# Out:
# Epoch 1/300
# 3/3 [==============================] - 1s 294ms/step - loss: 0.3999 - accuracy: 0.6050 - val_loss: 0.3690 - val_accuracy: 0.9000
# Epoch 2/300
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4010 - accuracy: 0.6250 - val_loss: 0.3619 - val_accuracy: 0.8800
# Epoch 3/300
# 3/3 [==============================] - 1s 310ms/step - loss: 0.3978 - accuracy: 0.6350 - val_loss: 0.3693 - val_accuracy: 0.8000
# Epoch 4/300
# 3/3 [==============================] - 0s 174ms/step - loss: 0.3969 - accuracy: 0.6200 - val_loss: 0.3700 - val_accuracy: 0.8600
# Epoch 5/300
# 3/3 [==============================] - 0s 147ms/step - loss: 0.3965 - accuracy: 0.6900 - val_loss: 0.3694 - val_accuracy: 0.8400
# Epoch 6/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.3946 - accuracy: 0.6250 - val_loss: 0.3663 - val_accuracy: 0.8800
# Epoch 7/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.3946 - accuracy: 0.6650 - val_loss: 0.3656 - val_accuracy: 0.8600
# Epoch 8/300
# 3/3 [==============================] - 0s 144ms/step - loss: 0.3934 - accuracy: 0.6100 - val_loss: 0.3651 - val_accuracy: 0.8600
# Epoch 9/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3916 - accuracy: 0.7150 - val_loss: 0.3641 - val_accuracy: 0.8200
# Epoch 10/300
# 3/3 [==============================] - 0s 158ms/step - loss: 0.3899 - accuracy: 0.6150 - val_loss: 0.3607 - val_accuracy: 0.8000
# Epoch 11/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3900 - accuracy: 0.6550 - val_loss: 0.3607 - val_accuracy: 0.8000
# Epoch 12/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.3874 - accuracy: 0.6600 - val_loss: 0.3647 - val_accuracy: 0.8800
# Epoch 13/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3873 - accuracy: 0.6100 - val_loss: 0.3642 - val_accuracy: 0.9000
# Epoch 14/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.3865 - accuracy: 0.6000 - val_loss: 0.3590 - val_accuracy: 0.8600
# Epoch 15/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3855 - accuracy: 0.6350 - val_loss: 0.3581 - val_accuracy: 0.8600
# Epoch 16/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3841 - accuracy: 0.6200 - val_loss: 0.3572 - val_accuracy: 0.8000
# Epoch 17/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.3812 - accuracy: 0.5800 - val_loss: 0.3560 - val_accuracy: 0.7600
# Epoch 18/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3814 - accuracy: 0.6300 - val_loss: 0.3574 - val_accuracy: 0.8800
# Epoch 19/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3800 - accuracy: 0.6350 - val_loss: 0.3569 - val_accuracy: 0.8400
# Epoch 20/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3792 - accuracy: 0.6000 - val_loss: 0.3566 - val_accuracy: 0.8400
# Epoch 21/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.3776 - accuracy: 0.6100 - val_loss: 0.3556 - val_accuracy: 0.8400
# Epoch 22/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.3760 - accuracy: 0.6650 - val_loss: 0.3570 - val_accuracy: 0.8400
# Epoch 23/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.3773 - accuracy: 0.6100 - val_loss: 0.3558 - val_accuracy: 0.8600
# Epoch 24/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3752 - accuracy: 0.6550 - val_loss: 0.3579 - val_accuracy: 0.8400
# Epoch 25/300
# 3/3 [==============================] - 0s 156ms/step - loss: 0.3739 - accuracy: 0.6150 - val_loss: 0.3552 - val_accuracy: 0.8600
# Epoch 26/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3717 - accuracy: 0.5800 - val_loss: 0.3523 - val_accuracy: 0.9000
# Epoch 27/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.3717 - accuracy: 0.6500 - val_loss: 0.3485 - val_accuracy: 0.8600
# Epoch 28/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.3717 - accuracy: 0.6400 - val_loss: 0.3483 - val_accuracy: 0.9000
# Epoch 29/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3690 - accuracy: 0.6800 - val_loss: 0.3456 - val_accuracy: 0.8600
# Epoch 30/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.3681 - accuracy: 0.6100 - val_loss: 0.3456 - val_accuracy: 0.8800
# Epoch 31/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3678 - accuracy: 0.6250 - val_loss: 0.3460 - val_accuracy: 0.8800
# Epoch 32/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3656 - accuracy: 0.6150 - val_loss: 0.3440 - val_accuracy: 0.8400
# Epoch 33/300
# 3/3 [==============================] - 0s 157ms/step - loss: 0.3651 - accuracy: 0.6400 - val_loss: 0.3427 - val_accuracy: 0.8600
# Epoch 34/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3645 - accuracy: 0.6650 - val_loss: 0.3431 - val_accuracy: 0.8600
# Epoch 35/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3644 - accuracy: 0.6400 - val_loss: 0.3412 - val_accuracy: 0.8800
# Epoch 36/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3630 - accuracy: 0.6350 - val_loss: 0.3371 - val_accuracy: 0.8600
# Epoch 37/300
# 3/3 [==============================] - 0s 158ms/step - loss: 0.3614 - accuracy: 0.6250 - val_loss: 0.3350 - val_accuracy: 0.9200
# Epoch 38/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3602 - accuracy: 0.6400 - val_loss: 0.3343 - val_accuracy: 0.8800
# Epoch 39/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.3582 - accuracy: 0.7150 - val_loss: 0.3300 - val_accuracy: 0.8800
# Epoch 40/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.3590 - accuracy: 0.6300 - val_loss: 0.3324 - val_accuracy: 0.8400
# Epoch 41/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.3582 - accuracy: 0.6650 - val_loss: 0.3296 - val_accuracy: 0.8600
# Epoch 42/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3563 - accuracy: 0.6600 - val_loss: 0.3318 - val_accuracy: 0.8200
# Epoch 43/300
# 3/3 [==============================] - 0s 176ms/step - loss: 0.3560 - accuracy: 0.6800 - val_loss: 0.3300 - val_accuracy: 0.8200
# Epoch 44/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3549 - accuracy: 0.6400 - val_loss: 0.3269 - val_accuracy: 0.8600
# Epoch 45/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3527 - accuracy: 0.6550 - val_loss: 0.3299 - val_accuracy: 0.8000
# Epoch 46/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.3534 - accuracy: 0.6700 - val_loss: 0.3311 - val_accuracy: 0.8800
# Epoch 47/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.3520 - accuracy: 0.6400 - val_loss: 0.3260 - val_accuracy: 0.8400
# Epoch 48/300
# 3/3 [==============================] - 0s 158ms/step - loss: 0.3513 - accuracy: 0.6850 - val_loss: 0.3265 - val_accuracy: 0.8800
# Epoch 49/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3497 - accuracy: 0.6100 - val_loss: 0.3233 - val_accuracy: 0.8400
# Epoch 50/300
# 3/3 [==============================] - 0s 171ms/step - loss: 0.3492 - accuracy: 0.7350 - val_loss: 0.3223 - val_accuracy: 0.8600
# Epoch 51/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3476 - accuracy: 0.6200 - val_loss: 0.3283 - val_accuracy: 0.8800
# Epoch 52/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3457 - accuracy: 0.6450 - val_loss: 0.3264 - val_accuracy: 0.8800
# Epoch 53/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3459 - accuracy: 0.6000 - val_loss: 0.3284 - val_accuracy: 0.8800
# Epoch 54/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3450 - accuracy: 0.6350 - val_loss: 0.3271 - val_accuracy: 0.9000
# Epoch 55/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3434 - accuracy: 0.6500 - val_loss: 0.3257 - val_accuracy: 0.8400
# Epoch 56/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3430 - accuracy: 0.6650 - val_loss: 0.3252 - val_accuracy: 0.9000
# Epoch 57/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3418 - accuracy: 0.6400 - val_loss: 0.3252 - val_accuracy: 0.9000
# Epoch 58/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3414 - accuracy: 0.6300 - val_loss: 0.3244 - val_accuracy: 0.8600
# Epoch 59/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3400 - accuracy: 0.6350 - val_loss: 0.3236 - val_accuracy: 0.8800
# Epoch 60/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3398 - accuracy: 0.6450 - val_loss: 0.3224 - val_accuracy: 0.8800
# Epoch 61/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3385 - accuracy: 0.5500 - val_loss: 0.3222 - val_accuracy: 0.9200
# Epoch 62/300
# 3/3 [==============================] - 0s 168ms/step - loss: 0.3377 - accuracy: 0.6300 - val_loss: 0.3214 - val_accuracy: 0.9400
# Epoch 63/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.3367 - accuracy: 0.6400 - val_loss: 0.3161 - val_accuracy: 0.8600
# Epoch 64/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3353 - accuracy: 0.7050 - val_loss: 0.3175 - val_accuracy: 0.8600
# Epoch 65/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3354 - accuracy: 0.6850 - val_loss: 0.3154 - val_accuracy: 0.7800
# Epoch 66/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.3342 - accuracy: 0.5950 - val_loss: 0.3167 - val_accuracy: 0.8200
# Epoch 67/300
# 3/3 [==============================] - 0s 168ms/step - loss: 0.3343 - accuracy: 0.6700 - val_loss: 0.3142 - val_accuracy: 0.8000
# Epoch 68/300
# 3/3 [==============================] - 0s 158ms/step - loss: 0.3325 - accuracy: 0.6000 - val_loss: 0.3170 - val_accuracy: 0.8600
# Epoch 69/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3307 - accuracy: 0.6500 - val_loss: 0.3163 - val_accuracy: 0.8800
# Epoch 70/300
# 3/3 [==============================] - 0s 158ms/step - loss: 0.3298 - accuracy: 0.6300 - val_loss: 0.3161 - val_accuracy: 0.9200
# Epoch 71/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3303 - accuracy: 0.6500 - val_loss: 0.3157 - val_accuracy: 0.9200
# Epoch 72/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3292 - accuracy: 0.6550 - val_loss: 0.3124 - val_accuracy: 0.9200
# Epoch 73/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.3280 - accuracy: 0.5700 - val_loss: 0.3121 - val_accuracy: 0.9000
# Epoch 74/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.3275 - accuracy: 0.6450 - val_loss: 0.3119 - val_accuracy: 0.9400
# Epoch 75/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3266 - accuracy: 0.6000 - val_loss: 0.3123 - val_accuracy: 0.9200
# Epoch 76/300
# 3/3 [==============================] - 0s 170ms/step - loss: 0.3250 - accuracy: 0.6000 - val_loss: 0.3129 - val_accuracy: 0.8800
# Epoch 77/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.3240 - accuracy: 0.6150 - val_loss: 0.3118 - val_accuracy: 0.9000
# Epoch 78/300
# 3/3 [==============================] - 0s 170ms/step - loss: 0.3239 - accuracy: 0.5750 - val_loss: 0.3102 - val_accuracy: 0.9000
# Epoch 79/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3234 - accuracy: 0.5750 - val_loss: 0.3093 - val_accuracy: 0.9200
# Epoch 80/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3218 - accuracy: 0.6200 - val_loss: 0.3049 - val_accuracy: 0.8600
# Epoch 81/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.3217 - accuracy: 0.5700 - val_loss: 0.3039 - val_accuracy: 0.8800
# Epoch 82/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3203 - accuracy: 0.6700 - val_loss: 0.3050 - val_accuracy: 0.8800
# Epoch 83/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3195 - accuracy: 0.6200 - val_loss: 0.3049 - val_accuracy: 0.8200
# Epoch 84/300
# 3/3 [==============================] - 0s 155ms/step - loss: 0.3191 - accuracy: 0.6700 - val_loss: 0.3046 - val_accuracy: 0.8000
# Epoch 85/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3175 - accuracy: 0.5800 - val_loss: 0.3057 - val_accuracy: 0.8200
# Epoch 86/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3172 - accuracy: 0.6350 - val_loss: 0.3047 - val_accuracy: 0.8200
# Epoch 87/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.3173 - accuracy: 0.6400 - val_loss: 0.3024 - val_accuracy: 0.9000
# Epoch 88/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3153 - accuracy: 0.6200 - val_loss: 0.3016 - val_accuracy: 0.8800
# Epoch 89/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.3147 - accuracy: 0.6000 - val_loss: 0.2988 - val_accuracy: 0.8200
# Epoch 90/300
# 3/3 [==============================] - 0s 170ms/step - loss: 0.3139 - accuracy: 0.7250 - val_loss: 0.2980 - val_accuracy: 0.8200
# Epoch 91/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3128 - accuracy: 0.6900 - val_loss: 0.3001 - val_accuracy: 0.8400
# Epoch 92/300
# 3/3 [==============================] - 0s 171ms/step - loss: 0.3121 - accuracy: 0.6150 - val_loss: 0.2982 - val_accuracy: 0.8000
# Epoch 93/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.3117 - accuracy: 0.6700 - val_loss: 0.2978 - val_accuracy: 0.8400
# Epoch 94/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.3104 - accuracy: 0.6150 - val_loss: 0.2980 - val_accuracy: 0.8800
# Epoch 95/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.3103 - accuracy: 0.5900 - val_loss: 0.2918 - val_accuracy: 0.7400
# Epoch 96/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3090 - accuracy: 0.6300 - val_loss: 0.2931 - val_accuracy: 0.6800
# Epoch 97/300
# 3/3 [==============================] - 0s 171ms/step - loss: 0.3086 - accuracy: 0.6550 - val_loss: 0.2901 - val_accuracy: 0.7600
# Epoch 98/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.3079 - accuracy: 0.6500 - val_loss: 0.2911 - val_accuracy: 0.7000
# Epoch 99/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.3076 - accuracy: 0.6050 - val_loss: 0.2903 - val_accuracy: 0.7200
# Epoch 100/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3067 - accuracy: 0.6400 - val_loss: 0.2879 - val_accuracy: 0.8200
# Epoch 101/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.3040 - accuracy: 0.6550 - val_loss: 0.2868 - val_accuracy: 0.8200
# Epoch 102/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.3053 - accuracy: 0.6450 - val_loss: 0.2856 - val_accuracy: 0.8200
# Epoch 103/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.3041 - accuracy: 0.6600 - val_loss: 0.2863 - val_accuracy: 0.8200
# Epoch 104/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3029 - accuracy: 0.6100 - val_loss: 0.2872 - val_accuracy: 0.8600
# Epoch 105/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3024 - accuracy: 0.6350 - val_loss: 0.2884 - val_accuracy: 0.7800
# Epoch 106/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3019 - accuracy: 0.5600 - val_loss: 0.2848 - val_accuracy: 0.7800
# Epoch 107/300
# 3/3 [==============================] - 0s 158ms/step - loss: 0.3010 - accuracy: 0.5950 - val_loss: 0.2849 - val_accuracy: 0.8000
# Epoch 108/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3004 - accuracy: 0.6650 - val_loss: 0.2897 - val_accuracy: 0.8600
# Epoch 109/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.2991 - accuracy: 0.6200 - val_loss: 0.2881 - val_accuracy: 0.8200
# Epoch 110/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.2991 - accuracy: 0.6150 - val_loss: 0.2873 - val_accuracy: 0.8000
# Epoch 111/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.2977 - accuracy: 0.6450 - val_loss: 0.2872 - val_accuracy: 0.8000
# Epoch 112/300
# 3/3 [==============================] - 0s 171ms/step - loss: 0.2971 - accuracy: 0.6550 - val_loss: 0.2865 - val_accuracy: 0.7800
# Epoch 113/300
# 3/3 [==============================] - 0s 175ms/step - loss: 0.2966 - accuracy: 0.7000 - val_loss: 0.2870 - val_accuracy: 0.8200
# Epoch 114/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2955 - accuracy: 0.6550 - val_loss: 0.2867 - val_accuracy: 0.8200
# Epoch 115/300
# 3/3 [==============================] - 0s 170ms/step - loss: 0.2945 - accuracy: 0.6650 - val_loss: 0.2855 - val_accuracy: 0.8000
# Epoch 116/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.2941 - accuracy: 0.5750 - val_loss: 0.2850 - val_accuracy: 0.8200
# Epoch 117/300
# 3/3 [==============================] - 0s 158ms/step - loss: 0.2934 - accuracy: 0.6150 - val_loss: 0.2844 - val_accuracy: 0.8800
# Epoch 118/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.2933 - accuracy: 0.5750 - val_loss: 0.2843 - val_accuracy: 0.9000
# Epoch 119/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.2925 - accuracy: 0.6550 - val_loss: 0.2829 - val_accuracy: 0.8800
# Epoch 120/300
# 3/3 [==============================] - 0s 167ms/step - loss: 0.2920 - accuracy: 0.5600 - val_loss: 0.2829 - val_accuracy: 0.8800
# Epoch 121/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.2912 - accuracy: 0.5950 - val_loss: 0.2813 - val_accuracy: 0.8400
# Epoch 122/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.2905 - accuracy: 0.7200 - val_loss: 0.2809 - val_accuracy: 0.8400
# Epoch 123/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.2890 - accuracy: 0.6550 - val_loss: 0.2795 - val_accuracy: 0.8000
# Epoch 124/300
# 3/3 [==============================] - 0s 157ms/step - loss: 0.2884 - accuracy: 0.6200 - val_loss: 0.2787 - val_accuracy: 0.8200
# Epoch 125/300
# 3/3 [==============================] - 0s 169ms/step - loss: 0.2878 - accuracy: 0.6550 - val_loss: 0.2784 - val_accuracy: 0.8200
# Epoch 126/300
# 3/3 [==============================] - 0s 157ms/step - loss: 0.2870 - accuracy: 0.6650 - val_loss: 0.2779 - val_accuracy: 0.8400
# Epoch 127/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.2868 - accuracy: 0.5800 - val_loss: 0.2789 - val_accuracy: 0.8600
# Epoch 128/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.2863 - accuracy: 0.6250 - val_loss: 0.2785 - val_accuracy: 0.8800
# Epoch 129/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2852 - accuracy: 0.6300 - val_loss: 0.2779 - val_accuracy: 0.8800
# Epoch 130/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.2850 - accuracy: 0.6650 - val_loss: 0.2764 - val_accuracy: 0.8400
# Epoch 131/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.2837 - accuracy: 0.5900 - val_loss: 0.2740 - val_accuracy: 0.8400
# Epoch 132/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.2834 - accuracy: 0.6900 - val_loss: 0.2722 - val_accuracy: 0.8800
# Epoch 133/300
# 3/3 [==============================] - 0s 157ms/step - loss: 0.2832 - accuracy: 0.6200 - val_loss: 0.2727 - val_accuracy: 0.8400
# Epoch 134/300
# 3/3 [==============================] - 0s 168ms/step - loss: 0.2815 - accuracy: 0.6200 - val_loss: 0.2724 - val_accuracy: 0.8600
# Epoch 135/300
# 3/3 [==============================] - 0s 168ms/step - loss: 0.2809 - accuracy: 0.6350 - val_loss: 0.2682 - val_accuracy: 0.8600
# Epoch 136/300
# 3/3 [==============================] - 0s 175ms/step - loss: 0.2809 - accuracy: 0.6800 - val_loss: 0.2673 - val_accuracy: 0.8800
# Epoch 137/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.2805 - accuracy: 0.6950 - val_loss: 0.2676 - val_accuracy: 0.8600
# Epoch 138/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.2793 - accuracy: 0.6400 - val_loss: 0.2694 - val_accuracy: 0.8600
# Epoch 139/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2788 - accuracy: 0.6350 - val_loss: 0.2678 - val_accuracy: 0.8400
# Epoch 140/300
# 3/3 [==============================] - 0s 168ms/step - loss: 0.2780 - accuracy: 0.6200 - val_loss: 0.2687 - val_accuracy: 0.8600
# Epoch 141/300
# 3/3 [==============================] - 0s 170ms/step - loss: 0.2770 - accuracy: 0.5550 - val_loss: 0.2691 - val_accuracy: 0.8400
# Epoch 142/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.2768 - accuracy: 0.6400 - val_loss: 0.2696 - val_accuracy: 0.8400
# Epoch 143/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.2767 - accuracy: 0.5700 - val_loss: 0.2684 - val_accuracy: 0.8600
# Epoch 144/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.2754 - accuracy: 0.6250 - val_loss: 0.2685 - val_accuracy: 0.8400
# Epoch 145/300
# 3/3 [==============================] - 0s 172ms/step - loss: 0.2752 - accuracy: 0.6250 - val_loss: 0.2677 - val_accuracy: 0.8600
# Epoch 146/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.2745 - accuracy: 0.6050 - val_loss: 0.2674 - val_accuracy: 0.8600
# Epoch 147/300
# 3/3 [==============================] - 0s 158ms/step - loss: 0.2731 - accuracy: 0.6150 - val_loss: 0.2663 - val_accuracy: 0.8800
# Epoch 148/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.2728 - accuracy: 0.6500 - val_loss: 0.2674 - val_accuracy: 0.8800
# Epoch 149/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.2726 - accuracy: 0.5750 - val_loss: 0.2665 - val_accuracy: 0.8600
# Epoch 150/300
# 3/3 [==============================] - 0s 169ms/step - loss: 0.2716 - accuracy: 0.6050 - val_loss: 0.2673 - val_accuracy: 0.9200
# Epoch 151/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2713 - accuracy: 0.6300 - val_loss: 0.2663 - val_accuracy: 0.9000
# Epoch 152/300
# 3/3 [==============================] - 0s 173ms/step - loss: 0.2706 - accuracy: 0.6300 - val_loss: 0.2651 - val_accuracy: 0.8800
# Epoch 153/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.2697 - accuracy: 0.6350 - val_loss: 0.2647 - val_accuracy: 0.8800
# Epoch 154/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.2694 - accuracy: 0.6850 - val_loss: 0.2645 - val_accuracy: 0.8800
# Epoch 155/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.2681 - accuracy: 0.5950 - val_loss: 0.2638 - val_accuracy: 0.8600
# Epoch 156/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.2682 - accuracy: 0.6800 - val_loss: 0.2632 - val_accuracy: 0.8800
# Epoch 157/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2672 - accuracy: 0.6350 - val_loss: 0.2629 - val_accuracy: 0.9200
# Epoch 158/300
# 3/3 [==============================] - 0s 174ms/step - loss: 0.2668 - accuracy: 0.6300 - val_loss: 0.2621 - val_accuracy: 0.8600
# Epoch 159/300
# 3/3 [==============================] - 0s 178ms/step - loss: 0.2655 - accuracy: 0.6300 - val_loss: 0.2614 - val_accuracy: 0.8800
# Epoch 160/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2653 - accuracy: 0.5750 - val_loss: 0.2610 - val_accuracy: 0.8600
# Epoch 161/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2648 - accuracy: 0.6950 - val_loss: 0.2607 - val_accuracy: 0.9000
# Epoch 162/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.2641 - accuracy: 0.6350 - val_loss: 0.2606 - val_accuracy: 0.9200
# Epoch 163/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.2639 - accuracy: 0.6200 - val_loss: 0.2605 - val_accuracy: 0.9200
# Epoch 164/300
# 3/3 [==============================] - 0s 169ms/step - loss: 0.2632 - accuracy: 0.6000 - val_loss: 0.2599 - val_accuracy: 0.9200
# Epoch 165/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.2629 - accuracy: 0.6450 - val_loss: 0.2584 - val_accuracy: 0.9200
# Epoch 166/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.2625 - accuracy: 0.5800 - val_loss: 0.2578 - val_accuracy: 0.9200
# Epoch 167/300
# 3/3 [==============================] - 0s 160ms/step - loss: 0.2613 - accuracy: 0.6450 - val_loss: 0.2564 - val_accuracy: 0.8600
# Epoch 168/300
# 3/3 [==============================] - 0s 166ms/step - loss: 0.2612 - accuracy: 0.6250 - val_loss: 0.2557 - val_accuracy: 0.8800
# Epoch 169/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.2604 - accuracy: 0.5950 - val_loss: 0.2549 - val_accuracy: 0.8600
# Epoch 170/300
# 3/3 [==============================] - 0s 164ms/step - loss: 0.2600 - accuracy: 0.6000 - val_loss: 0.2530 - val_accuracy: 0.8600
# Epoch 171/300
# 3/3 [==============================] - 1s 210ms/step - loss: 0.2597 - accuracy: 0.6550 - val_loss: 0.2531 - val_accuracy: 0.8800
# Epoch 172/300
# 3/3 [==============================] - 0s 170ms/step - loss: 0.2590 - accuracy: 0.7050 - val_loss: 0.2509 - val_accuracy: 0.8800
# Epoch 173/300
# 3/3 [==============================] - 1s 167ms/step - loss: 0.2576 - accuracy: 0.6300 - val_loss: 0.2539 - val_accuracy: 0.9200
# Epoch 174/300
# 3/3 [==============================] - 0s 162ms/step - loss: 0.2573 - accuracy: 0.6400 - val_loss: 0.2530 - val_accuracy: 0.9200
# Epoch 175/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.2572 - accuracy: 0.6100 - val_loss: 0.2524 - val_accuracy: 0.9200
# Epoch 176/300
# 3/3 [==============================] - 0s 161ms/step - loss: 0.2561 - accuracy: 0.6700 - val_loss: 0.2513 - val_accuracy: 0.9200
# Epoch 177/300
# 3/3 [==============================] - 0s 176ms/step - loss: 0.2562 - accuracy: 0.6150 - val_loss: 0.2514 - val_accuracy: 0.9200
# Epoch 178/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.2556 - accuracy: 0.5900 - val_loss: 0.2498 - val_accuracy: 0.9800
# Epoch 179/300
# 3/3 [==============================] - 0s 159ms/step - loss: 0.2552 - accuracy: 0.6650 - val_loss: 0.2496 - val_accuracy: 0.9800
# Epoch 180/300
# 3/3 [==============================] - 0s 163ms/step - loss: 0.2536 - accuracy: 0.6700 - val_loss: 0.2492 - val_accuracy: 0.9800
# Epoch 181/300
# 3/3 [==============================] - 0s 165ms/step - loss: 0.2536 - accuracy: 0.6250 - val_loss: 0.2476 - val_accuracy: 0.9200
# Epoch 182/300
# 3/3 [==============================] - 0s 170ms/step - loss: 0.2532 - accuracy: 0.6600 - val_loss: 0.2474 - val_accuracy: 0.9400
# Epoch 183/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2530 - accuracy: 0.6050 - val_loss: 0.2468 - val_accuracy: 0.9800
# Epoch 184/300
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2509 - accuracy: 0.6600 - val_loss: 0.2467 - val_accuracy: 0.9400
# Epoch 185/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2517 - accuracy: 0.6700 - val_loss: 0.2472 - val_accuracy: 0.9800
# Epoch 186/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2508 - accuracy: 0.6450 - val_loss: 0.2468 - val_accuracy: 0.9200
# Epoch 187/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2505 - accuracy: 0.5800 - val_loss: 0.2436 - val_accuracy: 0.9200
# Epoch 188/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2501 - accuracy: 0.6700 - val_loss: 0.2446 - val_accuracy: 0.9200
# Epoch 189/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2495 - accuracy: 0.6550 - val_loss: 0.2441 - val_accuracy: 0.9000
# Epoch 190/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2486 - accuracy: 0.6700 - val_loss: 0.2454 - val_accuracy: 0.8600
# Epoch 191/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2483 - accuracy: 0.6750 - val_loss: 0.2444 - val_accuracy: 0.9000
# Epoch 192/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2477 - accuracy: 0.6000 - val_loss: 0.2418 - val_accuracy: 0.8800
# Epoch 193/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2470 - accuracy: 0.7150 - val_loss: 0.2404 - val_accuracy: 0.9000
# Epoch 194/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2464 - accuracy: 0.5900 - val_loss: 0.2410 - val_accuracy: 0.9000
# Epoch 195/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2458 - accuracy: 0.6100 - val_loss: 0.2401 - val_accuracy: 0.9000
# Epoch 196/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2454 - accuracy: 0.6450 - val_loss: 0.2393 - val_accuracy: 0.9000
# Epoch 197/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2452 - accuracy: 0.5450 - val_loss: 0.2404 - val_accuracy: 0.8600
# Epoch 198/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2446 - accuracy: 0.6100 - val_loss: 0.2395 - val_accuracy: 0.8800
# Epoch 199/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2444 - accuracy: 0.6000 - val_loss: 0.2390 - val_accuracy: 0.8600
# Epoch 200/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2436 - accuracy: 0.6050 - val_loss: 0.2391 - val_accuracy: 0.9200
# Epoch 201/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2420 - accuracy: 0.6600 - val_loss: 0.2381 - val_accuracy: 0.9000
# Epoch 202/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2429 - accuracy: 0.6100 - val_loss: 0.2366 - val_accuracy: 0.8800
# Epoch 203/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2418 - accuracy: 0.6250 - val_loss: 0.2354 - val_accuracy: 0.8600
# Epoch 204/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2413 - accuracy: 0.6350 - val_loss: 0.2335 - val_accuracy: 0.8600
# Epoch 205/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2408 - accuracy: 0.6000 - val_loss: 0.2340 - val_accuracy: 0.8800
# Epoch 206/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2410 - accuracy: 0.5900 - val_loss: 0.2327 - val_accuracy: 0.8600
# Epoch 207/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2394 - accuracy: 0.6500 - val_loss: 0.2334 - val_accuracy: 0.8600
# Epoch 208/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2397 - accuracy: 0.6250 - val_loss: 0.2334 - val_accuracy: 0.8800
# Epoch 209/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2388 - accuracy: 0.6400 - val_loss: 0.2336 - val_accuracy: 0.9200
# Epoch 210/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2383 - accuracy: 0.6250 - val_loss: 0.2337 - val_accuracy: 0.8600
# Epoch 211/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2381 - accuracy: 0.6750 - val_loss: 0.2315 - val_accuracy: 0.8800
# Epoch 212/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2369 - accuracy: 0.6150 - val_loss: 0.2314 - val_accuracy: 0.9000
# Epoch 213/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2371 - accuracy: 0.6050 - val_loss: 0.2296 - val_accuracy: 0.8600
# Epoch 214/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2363 - accuracy: 0.6650 - val_loss: 0.2309 - val_accuracy: 0.8200
# Epoch 215/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2359 - accuracy: 0.5950 - val_loss: 0.2321 - val_accuracy: 0.8600
# Epoch 216/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2354 - accuracy: 0.6350 - val_loss: 0.2317 - val_accuracy: 0.8600
# Epoch 217/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2347 - accuracy: 0.6450 - val_loss: 0.2275 - val_accuracy: 0.8400
# Epoch 218/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2349 - accuracy: 0.5950 - val_loss: 0.2287 - val_accuracy: 0.8000
# Epoch 219/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2337 - accuracy: 0.6650 - val_loss: 0.2289 - val_accuracy: 0.8400
# Epoch 220/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2336 - accuracy: 0.6200 - val_loss: 0.2288 - val_accuracy: 0.8800
# Epoch 221/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2327 - accuracy: 0.6800 - val_loss: 0.2289 - val_accuracy: 0.9000
# Epoch 222/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2326 - accuracy: 0.6700 - val_loss: 0.2296 - val_accuracy: 0.9000
# Epoch 223/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2324 - accuracy: 0.6700 - val_loss: 0.2300 - val_accuracy: 0.9400
# Epoch 224/300
# 3/3 [==============================] - 0s 149ms/step - loss: 0.2317 - accuracy: 0.7050 - val_loss: 0.2293 - val_accuracy: 0.9200
# Epoch 225/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2310 - accuracy: 0.6350 - val_loss: 0.2290 - val_accuracy: 0.9200
# Epoch 226/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2309 - accuracy: 0.6550 - val_loss: 0.2285 - val_accuracy: 0.9200
# Epoch 227/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2300 - accuracy: 0.5900 - val_loss: 0.2281 - val_accuracy: 0.9200
# Epoch 228/300
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2292 - accuracy: 0.6450 - val_loss: 0.2278 - val_accuracy: 0.9400
# Epoch 229/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2293 - accuracy: 0.6100 - val_loss: 0.2273 - val_accuracy: 0.9400
# Epoch 230/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2284 - accuracy: 0.6000 - val_loss: 0.2268 - val_accuracy: 0.9000
# Epoch 231/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2284 - accuracy: 0.6350 - val_loss: 0.2260 - val_accuracy: 0.8800
# Epoch 232/300
# 3/3 [==============================] - 1s 362ms/step - loss: 0.2278 - accuracy: 0.6650 - val_loss: 0.2258 - val_accuracy: 0.9200
# Epoch 233/300
# 3/3 [==============================] - 1s 175ms/step - loss: 0.2272 - accuracy: 0.6350 - val_loss: 0.2254 - val_accuracy: 0.9200
# Epoch 234/300
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2266 - accuracy: 0.6650 - val_loss: 0.2245 - val_accuracy: 0.9000
# Epoch 235/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2264 - accuracy: 0.5950 - val_loss: 0.2240 - val_accuracy: 0.9000
# Epoch 236/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2260 - accuracy: 0.6950 - val_loss: 0.2219 - val_accuracy: 0.9000
# Epoch 237/300
# 3/3 [==============================] - 1s 198ms/step - loss: 0.2252 - accuracy: 0.6400 - val_loss: 0.2216 - val_accuracy: 0.9000
# Epoch 238/300
# 3/3 [==============================] - 1s 314ms/step - loss: 0.2252 - accuracy: 0.6450 - val_loss: 0.2207 - val_accuracy: 0.8800
# Epoch 239/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2247 - accuracy: 0.5850 - val_loss: 0.2217 - val_accuracy: 0.9000
# Epoch 240/300
# 3/3 [==============================] - 0s 148ms/step - loss: 0.2244 - accuracy: 0.5950 - val_loss: 0.2217 - val_accuracy: 0.9000
# Epoch 241/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2238 - accuracy: 0.7000 - val_loss: 0.2208 - val_accuracy: 0.8800
# Epoch 242/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2237 - accuracy: 0.7050 - val_loss: 0.2201 - val_accuracy: 0.8800
# Epoch 243/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2235 - accuracy: 0.7300 - val_loss: 0.2198 - val_accuracy: 0.8800
# Epoch 244/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2227 - accuracy: 0.7400 - val_loss: 0.2193 - val_accuracy: 0.8800
# Epoch 245/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2227 - accuracy: 0.6750 - val_loss: 0.2195 - val_accuracy: 0.9000
# Epoch 246/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2217 - accuracy: 0.6650 - val_loss: 0.2189 - val_accuracy: 0.8600
# Epoch 247/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2214 - accuracy: 0.6200 - val_loss: 0.2187 - val_accuracy: 0.8800
# Epoch 248/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2207 - accuracy: 0.6600 - val_loss: 0.2184 - val_accuracy: 0.8800
# Epoch 249/300
# 3/3 [==============================] - 0s 148ms/step - loss: 0.2209 - accuracy: 0.6100 - val_loss: 0.2182 - val_accuracy: 0.9000
# Epoch 250/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2200 - accuracy: 0.6300 - val_loss: 0.2189 - val_accuracy: 0.8800
# Epoch 251/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2195 - accuracy: 0.6600 - val_loss: 0.2184 - val_accuracy: 0.9000
# Epoch 252/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2184 - accuracy: 0.6450 - val_loss: 0.2175 - val_accuracy: 0.9400
# Epoch 253/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2183 - accuracy: 0.6350 - val_loss: 0.2172 - val_accuracy: 0.9000
# Epoch 254/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2187 - accuracy: 0.6300 - val_loss: 0.2163 - val_accuracy: 0.9000
# Epoch 255/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2179 - accuracy: 0.6150 - val_loss: 0.2157 - val_accuracy: 0.9000
# Epoch 256/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2174 - accuracy: 0.6200 - val_loss: 0.2147 - val_accuracy: 0.9000
# Epoch 257/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2171 - accuracy: 0.6300 - val_loss: 0.2138 - val_accuracy: 0.8800
# Epoch 258/300
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2172 - accuracy: 0.6850 - val_loss: 0.2132 - val_accuracy: 0.8800
# Epoch 259/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2164 - accuracy: 0.6400 - val_loss: 0.2137 - val_accuracy: 0.9200
# Epoch 260/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2159 - accuracy: 0.6350 - val_loss: 0.2136 - val_accuracy: 0.9600
# Epoch 261/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2162 - accuracy: 0.6400 - val_loss: 0.2130 - val_accuracy: 0.9600
# Epoch 262/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2154 - accuracy: 0.6850 - val_loss: 0.2128 - val_accuracy: 0.9400
# Epoch 263/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2148 - accuracy: 0.5950 - val_loss: 0.2125 - val_accuracy: 0.9400
# Epoch 264/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2148 - accuracy: 0.6150 - val_loss: 0.2110 - val_accuracy: 0.9400
# Epoch 265/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2139 - accuracy: 0.6300 - val_loss: 0.2105 - val_accuracy: 0.9400
# Epoch 266/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2138 - accuracy: 0.6300 - val_loss: 0.2103 - val_accuracy: 0.9400
# Epoch 267/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2136 - accuracy: 0.6650 - val_loss: 0.2093 - val_accuracy: 0.9200
# Epoch 268/300
# 3/3 [==============================] - 0s 145ms/step - loss: 0.2134 - accuracy: 0.6100 - val_loss: 0.2090 - val_accuracy: 0.9000
# Epoch 269/300
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2123 - accuracy: 0.6500 - val_loss: 0.2091 - val_accuracy: 0.9000
# Epoch 270/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2121 - accuracy: 0.6250 - val_loss: 0.2079 - val_accuracy: 0.9000
# Epoch 271/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2118 - accuracy: 0.6900 - val_loss: 0.2076 - val_accuracy: 0.9200
# Epoch 272/300
# 3/3 [==============================] - 0s 145ms/step - loss: 0.2115 - accuracy: 0.6550 - val_loss: 0.2073 - val_accuracy: 0.9200
# Epoch 273/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2108 - accuracy: 0.6400 - val_loss: 0.2071 - val_accuracy: 0.9200
# Epoch 274/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2108 - accuracy: 0.6350 - val_loss: 0.2065 - val_accuracy: 0.9200
# Epoch 275/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2098 - accuracy: 0.6150 - val_loss: 0.2060 - val_accuracy: 0.9000
# Epoch 276/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2099 - accuracy: 0.6100 - val_loss: 0.2057 - val_accuracy: 0.9200
# Epoch 277/300
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2096 - accuracy: 0.6100 - val_loss: 0.2055 - val_accuracy: 0.9200
# Epoch 278/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2093 - accuracy: 0.6500 - val_loss: 0.2035 - val_accuracy: 0.8800
# Epoch 279/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2084 - accuracy: 0.6150 - val_loss: 0.2029 - val_accuracy: 0.9200
# Epoch 280/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2084 - accuracy: 0.6650 - val_loss: 0.2018 - val_accuracy: 0.9000
# Epoch 281/300
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2076 - accuracy: 0.6450 - val_loss: 0.2024 - val_accuracy: 0.8800
# Epoch 282/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2073 - accuracy: 0.5750 - val_loss: 0.2009 - val_accuracy: 0.8800
# Epoch 283/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2071 - accuracy: 0.6100 - val_loss: 0.2013 - val_accuracy: 0.8800
# Epoch 284/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2063 - accuracy: 0.6350 - val_loss: 0.2014 - val_accuracy: 0.9200
# Epoch 285/300
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2064 - accuracy: 0.6500 - val_loss: 0.2012 - val_accuracy: 0.9000
# Epoch 286/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2060 - accuracy: 0.6600 - val_loss: 0.1995 - val_accuracy: 0.9000
# Epoch 287/300
# 3/3 [==============================] - 0s 142ms/step - loss: 0.2051 - accuracy: 0.6600 - val_loss: 0.1987 - val_accuracy: 0.8800
# Epoch 288/300
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2049 - accuracy: 0.6450 - val_loss: 0.1996 - val_accuracy: 0.9200
# Epoch 289/300
# 3/3 [==============================] - 0s 144ms/step - loss: 0.2047 - accuracy: 0.6350 - val_loss: 0.1990 - val_accuracy: 0.9200
# Epoch 290/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2042 - accuracy: 0.6700 - val_loss: 0.1989 - val_accuracy: 0.8800
# Epoch 291/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2037 - accuracy: 0.6400 - val_loss: 0.1992 - val_accuracy: 0.9200
# Epoch 292/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2033 - accuracy: 0.6600 - val_loss: 0.1989 - val_accuracy: 0.9200
# Epoch 293/300
# 3/3 [==============================] - 0s 145ms/step - loss: 0.2034 - accuracy: 0.6750 - val_loss: 0.1992 - val_accuracy: 0.9200
# Epoch 294/300
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2027 - accuracy: 0.6500 - val_loss: 0.2004 - val_accuracy: 0.9000
# Epoch 295/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2026 - accuracy: 0.6700 - val_loss: 0.2005 - val_accuracy: 0.9800
# Epoch 296/300
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2019 - accuracy: 0.6450 - val_loss: 0.2003 - val_accuracy: 0.9400
# Epoch 297/300
# 3/3 [==============================] - 0s 139ms/step - loss: 0.2018 - accuracy: 0.7100 - val_loss: 0.2002 - val_accuracy: 0.9400
# Epoch 298/300
# 3/3 [==============================] - 0s 137ms/step - loss: 0.2011 - accuracy: 0.6350 - val_loss: 0.2006 - val_accuracy: 0.9600
# Epoch 299/300
# 3/3 [==============================] - 0s 138ms/step - loss: 0.2009 - accuracy: 0.6250 - val_loss: 0.2002 - val_accuracy: 0.9600
# Epoch 300/300
# 3/3 [==============================] - 0s 117ms/step - loss: 0.2002 - accuracy: 0.6050 - val_loss: 0.1995 - val_accuracy: 0.9600

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set()
acc = best_hist.history['accuracy']
val = best_hist.history['val_accuracy']
lossa = best_hist.history['loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training accuracy')
plt.plot(epochs, val, ':', label='Validation accuracy')
plt.plot(epochs, lossa, '_', label='Loss')
plt.title('Training and Validation Accuracy and Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy, Loss')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set()
acc = best_hist.history['accuracy']
val = best_hist.history['val_accuracy']
lossa = best_hist.history['loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training accuracy')
plt.plot(epochs, val, ':', label='Validation accuracy')
plt.plot(epochs, lossa, '_', label='Loss')
plt.title('Training and Validation Accuracy and Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy, Loss')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import confusion_matrix
y_predicted = best_model.predict(X_test) > 0.5
#mat = confusion_matrix(y_test, y_predicted)
mat = confusion_matrix(np.asarray(y_test).argmax(axis=1), np.asarray(y_predicted).argmax(axis=1))
labels_input=list(y_training_data.columns)
labels = labels_input

# %%
ax= plt.subplot()
sns.heatmap(mat, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(labels); ax.yaxis.set_ticklabels(labels);

# %%
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# Text(89.18, 0.5, 'Actual label')
